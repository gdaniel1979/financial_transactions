# %% [markdown]
# ### https://www.kaggle.com/datasets/computingvictor/transactions-fraud-datasets/data

# %% [markdown]
# ## Importing .csv files into 1000-row-dataframes

# %%
import pandas as pd

df_cards_data = pd.read_csv('cards_data.csv', nrows=1000, encoding='latin1', on_bad_lines='skip')
df_users_data = pd.read_csv('users_data.csv', nrows=1000, encoding='latin1', on_bad_lines='skip')
df_transactions_data = pd.read_csv('transactions_data.csv', nrows=1000, encoding='latin1', on_bad_lines='skip')

# %%
df_cards_data.head()
# Out:
#      id  client_id  card_brand        card_type       card_number  expires  \
# 0  4524        825        Visa            Debit  4344676511950444  12/2022
# 1  2731        825        Visa            Debit  4956965974959986  12/2020
# 2  3701        825        Visa            Debit  4582313478255491  02/2024
# 3    42        825        Visa           Credit  4879494103069057  08/2024
# 4  4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
#
#    cvv has_chip  num_cards_issued credit_limit acct_open_date  \
# 0  623      YES                 2       $24295        09/2002
# 1  393      YES                 2       $21968        04/2014
# 2  719      YES                 2       $46414        07/2003
# 3  693       NO                 1       $12400        01/2003
# 4   75      YES                 1          $28        09/2008
#
#    year_pin_last_changed card_on_dark_web
# 0                   2008               No
# 1                   2014               No
# 2                   2004               No
# 3                   2012               No
# 4                   2009               No

# %%
df_users_data.head().sort_values(by="id")
# Out:
#      id  current_age  retirement_age  birth_year  birth_month  gender  \
# 3   708           63              63        1957            1  Female
# 0   825           53              66        1966           11  Female
# 4  1164           43              70        1976            9    Male
# 2  1718           81              67        1938           11  Female
# 1  1746           53              68        1966           12  Female
#
#                     address  latitude  longitude per_capita_income  \
# 3          3 Madison Street     40.71     -73.99           $163145
# 0             462 Rose Lane     34.15    -117.76            $29278
# 4  9620 Valley Stream Drive     37.76    -122.44            $53797
# 2           766 Third Drive     34.02    -117.89            $22681
# 1    3606 Federal Boulevard     40.76     -73.74            $37891
#
#   yearly_income total_debt  credit_score  num_credit_cards
# 3       $249925    $202328           722                 4
# 0        $59696    $127613           787                 5
# 4       $109687    $183855           675                 1
# 2        $33483       $196           698                 5
# 1        $77254    $191349           701                 5

# %%
df_transactions_data.head()
# Out:
#         id                 date  client_id  card_id   amount  \
# 0  7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1  7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2  7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3  7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4  7475332  2010-01-01 00:06:00        848     3915   $46.41
#
#             use_chip  merchant_id merchant_city merchant_state      zip   mcc  \
# 0  Swipe Transaction        59935        Beulah             ND  58523.0  5499
# 1  Swipe Transaction        67570    Bettendorf             IA  52722.0  5311
# 2  Swipe Transaction        27092         Vista             CA  92084.0  4829
# 3  Swipe Transaction        27092   Crown Point             IN  46307.0  4829
# 4  Swipe Transaction        13051       Harwood             MD  20776.0  5813
#
#   errors
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# ## Importing .json files into 1000-item-dataframes

# %% [markdown]
# ### mcc_codes.json

# %%
import pandas as pd
import json

# 1. JSON fájl beolvasása Python dict-be
with open('mcc_codes.json', 'r', encoding='utf-8') as f:
    mcc_dict = json.load(f)

# 2. Dict átalakítása DataFrame-é
df_mcc_codes = pd.DataFrame(list(mcc_dict.items()), columns=['MCC', 'Description'])

# 3. Ellenőrzés
print(df_mcc_codes.head())
# Out:
#     MCC                           Description
# 0  5812         Eating Places and Restaurants
# 1  5541                      Service Stations
# 2  7996  Amusement Parks, Carnivals, Circuses
# 3  5411          Grocery Stores, Supermarkets
# 4  4784                 Tolls and Bridge Fees

# %%
df_mcc_codes.shape
# Out:
# (109, 2)

# %% [markdown]
# ### train_fraud_labels.json

# %%
import os

print("Fájl mérete MB-ban:", os.path.getsize('train_fraud_labels.jsonl') / (1024*1024))

with open('train_fraud_labels.jsonl', 'rb') as f:
    chunk = f.read(1000)
    print("Első 1000 byte:")
    print(chunk)
# Out:
# Fájl mérete MB-ban: 287.7449836730957
# Első 1000 byte:
# b'{"id": "10649266", "label": "No"}\n{"id": "23410063", "label": "No"}\n{"id": "9316588", "label": "No"}\n{"id": "12478022", "label": "No"}\n{"id": "9558530", "label": "No"}\n{"id": "12532830", "label": "No"}\n{"id": "19526714", "label": "No"}\n{"id": "9906964", "label": "No"}\n{"id": "13224888", "label": "No"}\n{"id": "13749094", "label": "No"}\n{"id": "12303776", "label": "No"}\n{"id": "19480376", "label": "No"}\n{"id": "11716050", "label": "No"}\n{"id": "20025400", "label": "No"}\n{"id": "7661688", "label": "No"}\n{"id": "16662807", "label": "No"}\n{"id": "21419778", "label": "No"}\n{"id": "18011186", "label": "No"}\n{"id": "23289598", "label": "No"}\n{"id": "11644547", "label": "No"}\n{"id": "23235120", "label": "No"}\n{"id": "19748218", "label": "No"}\n{"id": "8720720", "label": "No"}\n{"id": "18335831", "label": "No"}\n{"id": "18936727", "label": "No"}\n{"id": "15223870", "label": "No"}\n{"id": "12370203", "label": "No"}\n{"id": "17126661", "label": "No"}\n{"id": "22270430", "label": "No"}\n{"id": "18790248", '

# %% [raw]
# A fájl egy óriási egybefüggő JSON objektum, amely így néz ki:
# {
#   "Key": "target",
#   "Value": {
#       "10649266": "No",
#       "23410063": "No",
#       "9316588": "No",
#       ...
#       ... több tízmillió kulcs ...
#   }
# }
#
# A megoldás
# A JSON nem JSON-lines, ezért nem tudod "nrows=1000"-rel olvasni.
# Viszont: a fájlban a "Value" rész egy sima objektum → kulcs-érték párok tömege → ez streamelhető!
# ✔️ Így tudsz belőle csak 1000 sort kiszedni kernelhalál nélkül: Használj ijson-t, ami streameli a JSON-t (nem tölti be egyben).

# %% [raw]
# KONVERZIÓ: Nagy JSON → JSON Lines (streamelve, biztonságosan)

# %%
# Fájlszerkezet vizsgálata
import ijson

with open('train_fraud_labels.json', 'rb') as f:
    parser = ijson.parse(f)

    for prefix, event, value in parser:
        print(prefix, event, value)
        # álljunk le 30 token után
        if prefix.count('.') > 0:
            break
# Out:
#  start_map None
#  map_key target
# target start_map None
# target map_key 10649266
# target.10649266 string No

# %% [raw]
# # Többet nem kell futtatni, elkészítette a 287 MB-os .jsonl fájlt
#
# import ijson
# import json
#
# output_file = "train_fraud_labels.jsonl"
#
# count = 0
# with open('train_fraud_labels.json', 'rb') as f_in, open(output_file, 'w', encoding='utf-8') as f_out:
#     # streameljük a "target" dictionary kulcsait és értékeit
#     for key, value in ijson.kvitems(f_in, "target"):
#         f_out.write(json.dumps({"id": key, "label": value}) + "\n")
#         count += 1
#         #if count >= 1000000:
#         #    break
#
# print("Kész:", output_file)

# %% [raw]
# # Kernel dies
#
# import pandas as pd
#
# chunks = []
# chunk_size = 50000  # 50k rekordonként olvasunk
#
# for chunk in pd.read_json("train_fraud_labels.jsonl",
#                           lines=True,
#                           chunksize=chunk_size):
#     chunks.append(chunk)
#
# df = pd.concat(chunks, ignore_index=True)
# print(df.shape)
# print(df.head())

# %%
import pandas as pd

df_head = pd.read_json("train_fraud_labels.jsonl", lines=True, nrows=5)
df_head
# Out:
#          id label
# 0  10649266    No
# 1  23410063    No
# 2   9316588    No
# 3  12478022    No
# 4   9558530    No

# %%
import pandas as pd
df = pd.read_json("data/train_fraud_labels.jsonl", lines=True, nrows=100000)
df.isnull().sum()
# Out:
# id       0
# label    0
# dtype: int64
